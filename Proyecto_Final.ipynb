# %% [markdown]
# **Luis E. Ortiz Cotto**			#*801-16-5704*
#
# **Alex A. Ortiz Cotto** #*801-16-5701*
#
# > CCOM3031 Sec.0U1
#
# > *12/21/2021*
#
# # **Efectos del cambio climático en el planeta**

# %% [markdown]
# **Table of content for the file:** *GlobalLandTemperaturesByCity.csv*

# %%
city <- read.csv(file = "/content/GlobalLandTemperaturesByCity.csv")
city
# Out:
#        dt         AverageTemperature AverageTemperatureUncertainty City
# 1      1743-11-01  6.068             1.737                         Århus
# 2      1743-12-01     NA                NA                         Århus
# 3      1744-01-01     NA                NA                         Århus
# 4      1744-02-01     NA                NA                         Århus
# 5      1744-03-01     NA                NA                         Århus
# 6      1744-04-01  5.788             3.624                         Århus
# 7      1744-05-01 10.644             1.283                         Århus
# 8      1744-06-01 14.051             1.347                         Århus
# 9      1744-07-01 16.082             1.396                         Århus
# 10     1744-08-01     NA                NA                         Århus
# 11     1744-09-01 12.781             1.454                         Århus
# 12     1744-10-01  7.950             1.630                         Århus
# ...

# %% [markdown]
# **Table of content for the file:** *GlobalLandTemperaturesByCountry.csv*

# %%
country <- read.csv(file = "/content/GlobalLandTemperaturesByCountry.csv")
country
# Out:
#        dt         AverageTemperature AverageTemperatureUncertainty Country
# 1      1743-11-01  4.384             2.294                         Åland
# 2      1743-12-01     NA                NA                         Åland
# 3      1744-01-01     NA                NA                         Åland
# 4      1744-02-01     NA                NA                         Åland
# 5      1744-03-01     NA                NA                         Åland
# 6      1744-04-01  1.530             4.680                         Åland
# 7      1744-05-01  6.702             1.789                         Åland
# 8      1744-06-01 11.609             1.577                         Åland
# 9      1744-07-01 15.342             1.410                         Åland
# 10     1744-08-01     NA                NA                         Åland
# 11     1744-09-01 11.702             1.517                         Åland
# 12     1744-10-01  5.477             1.862                         Åland
# ...

# %% [markdown]
# **Table of content for the file:** *GlobalLandTemperaturesByMajorCity.csv*

# %%
major <- read.csv(file = "/content/GlobalLandTemperaturesByMajorCity.csv")
major
# Out:
#        dt         AverageTemperature AverageTemperatureUncertainty City
# 1      1849-01-01 26.704             1.435                         Abidjan
# 2      1849-02-01 27.434             1.362                         Abidjan
# 3      1849-03-01 28.101             1.612                         Abidjan
# 4      1849-04-01 26.140             1.387                         Abidjan
# 5      1849-05-01 25.427             1.200                         Abidjan
# 6      1849-06-01 24.844             1.402                         Abidjan
# 7      1849-07-01 24.058             1.254                         Abidjan
# 8      1849-08-01 23.576             1.265                         Abidjan
# 9      1849-09-01 23.662             1.226                         Abidjan
# 10     1849-10-01 25.263             1.175                         Abidjan
# 11     1849-11-01 26.332             1.507                         Abidjan
# 12     1849-12-01 25.450             1.838                         Abidjan
# ...

# %% [markdown]
# **Table of content for the file:** *GlobalLandTemperaturesByState.csv*

# %%
state <- read.csv(file = "/content/GlobalLandTemperaturesByState.csv")
state
# Out:
#        dt         AverageTemperature AverageTemperatureUncertainty State
# 1      1855-05-01 25.544             1.171                         Acre
# 2      1855-06-01 24.228             1.103                         Acre
# 3      1855-07-01 24.371             1.044                         Acre
# 4      1855-08-01 25.427             1.073                         Acre
# 5      1855-09-01 25.675             1.014                         Acre
# 6      1855-10-01 25.442             1.179                         Acre
# 7      1855-11-01 25.400             1.064                         Acre
# 8      1855-12-01 24.100             1.718                         Acre
# 9      1856-01-01 25.814             1.159                         Acre
# 10     1856-02-01 24.658             1.147                         Acre
# 11     1856-03-01 24.659             1.547                         Acre
# 12     1856-04-01 24.907             1.186                         Acre
# ...

# %% [markdown]
# **Table of content for the file:** *GlobalTemperatures.csv*

# %%
temp <- read.csv(file = "/content/GlobalTemperatures.csv")
temp
# Out:
#      dt         LandAverageTemperature LandAverageTemperatureUncertainty
# 1    1750-01-01  3.034                 3.574
# 2    1750-02-01  3.083                 3.702
# 3    1750-03-01  5.626                 3.076
# 4    1750-04-01  8.490                 2.451
# 5    1750-05-01 11.573                 2.072
# 6    1750-06-01 12.937                 1.724
# 7    1750-07-01 15.868                 1.911
# 8    1750-08-01 14.750                 2.231
# 9    1750-09-01 11.413                 2.637
# 10   1750-10-01  6.367                 2.668
# 11   1750-11-01     NA                    NA
# 12   1750-12-01  2.772                 2.970
# 13   1751-01-01  2.495                 3.469
# 14   1751-02-01  0.963                 3.827
# 15   1751-03-01  5.800                 3.051
# 16   1751-04-01  7.670                 2.368
# 17   1751-05-01     NA                    NA
# 18   1751-06-01 13.827                 1.801
# 19   1751-07-01     NA                    NA
# ...

# %% [markdown]
# Data From the Cities

# %% [markdown]
# It plots a graph of the temperature of the day in the city and the possible increase of the temperature.

# %%
library(ggplot2)
city <- read.csv(file = "/content/GlobalLandTemperaturesByCity.csv")

plot <- ggplot(city) +
        geom_line(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot

# %%
library(ggplot2)
city <- read.csv(file = "/content/GlobalLandTemperaturesByCity.csv")

plot <- ggplot(city) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 364130 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# This plot compares the temperature of each cities.

# %%
library(ggplot2)
city <- read.csv(file = "/content/GlobalLandTemperaturesByCity.csv")

plot <- ggplot(city) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red")) +
        facet_wrap(~City)

plot
# Out:
# Warning message:
# “Removed 364130 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Data from the Countries

# %% [markdown]
# It plots a graph of the temperature of the day in each country and the possible increase of the temperature.

# %%
library(ggplot2)
country <- read.csv(file = "/content/GlobalLandTemperaturesByCountry.csv")

plot <- ggplot(country) +
        geom_line(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 32651 row(s) containing missing values (geom_path).”
# plot without title

# %%
library(ggplot2)
country <- read.csv(file = "/content/GlobalLandTemperaturesByCountry.csv")

plot <- ggplot(country) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 32651 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# This plot compares the temperature in each country.

# %%
library(ggplot2)
country <- read.csv(file = "/content/GlobalLandTemperaturesByCountry.csv")

plot <- ggplot(country) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red")) +
        facet_wrap(~Country)

plot
# Out:
# Warning message:
# “Removed 32651 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Data from the Major Cities

# %% [markdown]
# It plots a graph of the temperature of the day in each major city and the possible increase of the temperature.

# %%
library(ggplot2)
major <- read.csv(file = "/content/GlobalLandTemperaturesByMajorCity.csv")

plot <- ggplot(major) +
        geom_line(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 11002 row(s) containing missing values (geom_path).”
# plot without title

# %%
library(ggplot2)
major <- read.csv(file = "/content/GlobalLandTemperaturesByMajorCity.csv")

plot <- ggplot(major) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 11002 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# This plot compares the temperature in each Major City.

# %%
library(ggplot2)
major <- read.csv(file = "/content/GlobalLandTemperaturesByMajorCity.csv")

plot <- ggplot(major) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red")) +
        facet_wrap(~Country)

plot
# Out:
# Warning message:
# “Removed 11002 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Data from the States

# %% [markdown]
# It plots a graph of the temperature of the day in each State and the possible increase of the temperature.

# %%
library(ggplot2)
state <- read.csv(file = "/content/GlobalLandTemperaturesByState.csv")

plot <- ggplot(state) +
        geom_line(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 25648 row(s) containing missing values (geom_path).”
# plot without title

# %%
library(ggplot2)
state <- read.csv(file = "/content/GlobalLandTemperaturesByState.csv")

plot <- ggplot(state) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red"))

plot
# Out:
# Warning message:
# “Removed 25648 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# This plot compares the temperature in each State.

# %%
library(ggplot2)
state <- read.csv(file = "/content/GlobalLandTemperaturesByState.csv")

plot <- ggplot(state) +
        geom_point(aes(x = AverageTemperature, y = AverageTemperatureUncertainty, color = "red")) +
        facet_wrap(~State)

plot
# Out:
# Warning message:
# “Removed 25648 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Global Data

# %% [markdown]
# It plots a graph of the temperature of the day of the World and the possible increase of the temperature.

# %%
library(ggplot2)
temp <- read.csv(file = "/content/GlobalTemperatures.csv")

plot <- ggplot(temp) +
        geom_line(aes(x = LandAndOceanAverageTemperature, y = LandAndOceanAverageTemperatureUncertainty, color = "red")) +
        geom_line(aes(x = LandAverageTemperature, y = LandAverageTemperatureUncertainty, color = "blue")) +
        geom_line(aes(x = LandMaxTemperature, y = LandMaxTemperatureUncertainty, color = "green")) +
        geom_line(aes(x = LandMinTemperature, y = LandMinTemperatureUncertainty, color = "yellow")) +
        xlab("Temperatures") +
        ylab("Temperatures Uncertainty")

plot
# Out:
# Warning message:
# “Removed 1200 row(s) containing missing values (geom_path).”
# Warning message:
# “Removed 12 row(s) containing missing values (geom_path).”
# Warning message:
# “Removed 1200 row(s) containing missing values (geom_path).”
# Warning message:
# “Removed 1200 row(s) containing missing values (geom_path).”
# plot without title

# %%
library(ggplot2)
temp <- read.csv(file = "/content/GlobalTemperatures.csv")

plot <- ggplot(temp) +
        geom_point(aes(x = LandAndOceanAverageTemperature, y = LandAndOceanAverageTemperatureUncertainty, color = "red")) +
        geom_point(aes(x = LandAverageTemperature, y = LandAverageTemperatureUncertainty, color = "blue")) +
        geom_point(aes(x = LandMaxTemperature, y = LandMaxTemperatureUncertainty, color = "green")) +
        geom_point(aes(x = LandMinTemperature, y = LandMinTemperatureUncertainty, color = "yellow")) +
        xlab("Temperatures") +
        ylab("Temperatures Uncertainty")

plot
# Out:
# Warning message:
# “Removed 1200 rows containing missing values (geom_point).”
# Warning message:
# “Removed 12 rows containing missing values (geom_point).”
# Warning message:
# “Removed 1200 rows containing missing values (geom_point).”
# Warning message:
# “Removed 1200 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# his plot compares the Global temperature for each year.

# %%
library(ggplot2)
temp <- read.csv(file = "/content/GlobalTemperatures.csv")

plot <- ggplot(temp) +
        geom_point(aes(x = LandAndOceanAverageTemperature, y = LandAndOceanAverageTemperatureUncertainty, color = "red")) +
        geom_point(aes(x = LandAverageTemperature, y = LandAverageTemperatureUncertainty, color = "blue")) +
        geom_point(aes(x = LandMaxTemperature, y = LandMaxTemperatureUncertainty, color = "green")) +
        geom_point(aes(x = LandMinTemperature, y = LandMinTemperatureUncertainty, color = "yellow")) +
        facet_wrap(~dt) +
        xlab("Temperatures") +
        ylab("Temperatures Uncertainty")

plot
# Out:
# Warning message:
# “Removed 1200 rows containing missing values (geom_point).”
# Warning message:
# “Removed 12 rows containing missing values (geom_point).”
# Warning message:
# “Removed 1200 rows containing missing values (geom_point).”
# Warning message:
# “Removed 1200 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Correlations between all the datas

# %% [markdown]
# The Correlation for temperature in the City.

# %%
city <- read.csv(file = "/content/GlobalLandTemperaturesByCity.csv")

val <- cor.test(city$AverageTemperature, city$AverageTemperatureUncertainty)
val
# Out:
# 	Pearson's product-moment correlation
#
# data:  city$AverageTemperature and city$AverageTemperatureUncertainty
# t = -458.9, df = 3918264, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2267828 -0.2249035
# sample estimates:
#        cor
# -0.2258433

# %% [markdown]
# The Correlation for temperature in the Country.

# %%
country <- read.csv(file = "/content/GlobalLandTemperaturesByCountry.csv")

val <- cor.test(country$AverageTemperature, country$AverageTemperatureUncertainty)
val
# Out:
# 	Pearson's product-moment correlation
#
# data:  country$AverageTemperature and country$AverageTemperatureUncertainty
# t = -236.42, df = 544809, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.3074475 -0.3026310
# sample estimates:
#        cor
# -0.3050412

# %% [markdown]
# The Correlation for temperature in the Major City.

# %%
major <- read.csv(file = "/content/GlobalLandTemperaturesByMajorCity.csv")

val <- cor.test(major$AverageTemperature, major$AverageTemperatureUncertainty)
val
# Out:
# 	Pearson's product-moment correlation
#
# data:  major$AverageTemperature and major$AverageTemperatureUncertainty
# t = -97.19, df = 228173, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2033168 -0.1954367
# sample estimates:
#      cor
# -0.19938

# %% [markdown]
# The Correlation for temperature in the State.

# %%
state <- read.csv(file = "/content/GlobalLandTemperaturesByState.csv")

val <- cor.test(state$AverageTemperature, state$AverageTemperatureUncertainty)
val
# Out:
# 	Pearson's product-moment correlation
#
# data:  state$AverageTemperature and state$AverageTemperatureUncertainty
# t = -180.91, df = 620025, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2262852 -0.2215566
# sample estimates:
#        cor
# -0.2239222

# %% [markdown]
# The Correlation for temperature in the World.

# %%
temp <- read.csv(file = "/content/GlobalTemperatures.csv")

val <- cor.test(temp$LandAndOceanAverageTemperature, temp$LandAndOceanAverageTemperatureUncertainty)
val

val1 <- cor.test(temp$LandAverageTemperature, temp$LandAverageTemperatureUncertainty)
val1

val2 <- cor.test(temp$LandMaxTemperature, temp$LandMaxTemperatureUncertainty)
val2

val3 <- cor.test(temp$LandMinTemperature, temp$LandMinTemperatureUncertainty)
val3

val4 <- cor.test(temp$LandAndOceanAverageTemperature, temp$LandAverageTemperature)
val4

val5 <- cor.test(temp$LandMaxTemperature, temp$LandMinTemperature)
val5
# Out:
# 	Pearson's product-moment correlation
#
# data:  temp$LandAndOceanAverageTemperature and temp$LandAndOceanAverageTemperatureUncertainty
# t = -9.2517, df = 1990, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2448071 -0.1605849
# sample estimates:
#        cor
# -0.2030716
# 	Pearson's product-moment correlation
#
# data:  temp$LandAverageTemperature and temp$LandAverageTemperatureUncertainty
# t = -11.759, df = 3178, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2372662 -0.1706437
# sample estimates:
#        cor
# -0.2041914
# 	Pearson's product-moment correlation
#
# data:  temp$LandMaxTemperature and temp$LandMaxTemperatureUncertainty
# t = -4.7258, df = 1990, p-value = 2.452e-06
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.14858014 -0.06171538
# sample estimates:
#        cor
# ...
